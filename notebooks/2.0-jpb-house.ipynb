# %%
import os
import sys
from pathlib import Path
import tensorflow as tf

PROJ_ROOT = os.path.join(os.pardir)
src_dir = os.path.join(PROJ_ROOT, 'src')
sys.path.append(src_dir)

from build_model import LoadResizeImages, HubStylizedImage

# %%
CONTENT_PATH = Path('contents')
content_name = 'johnpathouse.jpg'
content_path = os.path.join(PROJ_ROOT, CONTENT_PATH, content_name)

STYLE_PATH = Path('styles')
style_pastel = 'great-wave.jpg'
style_path = os.path.join(PROJ_ROOT, STYLE_PATH, style_pastel)

# path to save sytlized images
STYLIZED_PATH = Path('stylized_images')

# %%
house = LoadResizeImages(content_path, style_path, 512)

# %%
house.show_image(house.content_img)

# %%
house.content_img = house.rotate_image(house.content_img, 3)

# %%
house.show_image(house.content_img)

# %%
house.style_img = house.rotate_image(house.style_img, 3)

# %% [markdown]
# ## Great Wave

# %%
hub_wave = HubStylizedImage(house.content_img, house.style_img)

hub_wave.get_stylized_image()
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FF72C7AA190>

# %% [markdown]
# ## Starry-Night

# %%
style_starry = 'starry-night.jpg'
style_path = os.path.join(PROJ_ROOT, STYLE_PATH, style_starry)

house_starry = LoadResizeImages(content_path, style_path, 512)
house_starry.content_img = house_starry.rotate_image(
    house_starry.content_img, 3)
hub_starry = HubStylizedImage(house_starry.content_img,
                              house_starry.style_img)

hub_starry.get_stylized_image()
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FF72E76A850>

# %% [markdown]
# ## Pillars

# %%
style_pillars = 'pillars-of-creation.jpg'
style_path = os.path.join(PROJ_ROOT, STYLE_PATH, style_pillars)

house_pillars = LoadResizeImages(content_path, style_path, 512)
house_pillars.content_img = house_pillars.rotate_image(
    house_pillars.content_img, 3)
hub_pillars = HubStylizedImage(house_pillars.content_img,
                              house_pillars.style_img)

hub_pillars.get_stylized_image()
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FF70C150E10>

# %%
hub_pillars.save_image('pillars.png', 600, 850)

# %% [markdown]
# ## Colors

# %%
style_colors = 'colors.jpg'
style_path = os.path.join(PROJ_ROOT, STYLE_PATH, style_colors)

house_colors = LoadResizeImages(content_path, style_path, 512)
house_colors.content_img = house_colors.rotate_image(
    house_colors.content_img, 3)
hub_colors = HubStylizedImage(house_colors.content_img,
                              house_colors.style_img)

hub_colors.get_stylized_image()
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FF70A267E50>

# %% [markdown]
# # Kandinsky-7

# %%
style_k7 = 'kandinsky-7.jpg'
style_path = os.path.join(PROJ_ROOT, STYLE_PATH, style_k7)

house_k7 = LoadResizeImages(content_path, style_path, 512)
house_k7.content_img = house_k7.rotate_image(
    house_k7.content_img, 3)
hub_k7 = HubStylizedImage(house_k7.content_img,
                          house_k7.style_img)

hub_k7.get_stylized_image()
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FF6FF7C8BD0>

# %% [markdown]
# ## Kandinsky - 1913

# %%
style_k1913 = 'kandinsky-1913.jpg'
style_path = os.path.join(PROJ_ROOT, STYLE_PATH, style_k1913)

house_k1913 = LoadResizeImages(content_path, style_path, 512)
house_k1913.content_img = house_k1913.rotate_image(
    house_k1913.content_img, 3)
hub_k1913 = HubStylizedImage(house_k1913.content_img,
                          house_k1913.style_img)

hub_k1913.get_stylized_image()
# Out:
# <PIL.Image.Image image mode=RGB size=384x512 at 0x7FF66152DD50>
