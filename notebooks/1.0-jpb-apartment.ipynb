# %%
import os
import sys
from pathlib import Path
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow as tf

PROJ_ROOT = os.path.join(os.pardir)
src_dir = os.path.join(PROJ_ROOT, 'src')
sys.path.append(src_dir)

from clean_image import resize_image, show_image

# %%
CONTENT_PATH = Path('apartment_pics')
content_name = 'apartment1.jpg'

content_pic = os.path.join(PROJ_ROOT, CONTENT_PATH, content_name)
content_img = mpl.image.imread(content_pic)

STYLE_PATH = Path('style_pics')
style_name = 'krystal-ng.jpg'

style_pic = os.path.join(PROJ_ROOT, STYLE_PATH, style_name)
style_img = mpl.image.imread(style_pic)

# %%
plt.imshow(content_img)
plt.show()

# %%
# rotate counter-clockwise 270 degrees
content_img = tf.image.rot90(content_img, k=3)

# %%
plt.imshow(style_img)
plt.show()

# %%
content_img = resize_image(content_img)
style_img = resize_image(style_img)

# %%
show_image(content_img)

# %%
show_image(style_img)
